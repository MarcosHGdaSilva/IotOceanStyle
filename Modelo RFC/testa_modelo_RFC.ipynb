# %%
import pandas as pd
import joblib
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
data_teste = pd.read_csv("C:\\Users\\Marcos\\Desktop\\testes-de-modelo-para-treinamento-ruidos-\\virt_env\\myenv\\arquivos\\CSV\\features_audios_testes.csv")
tst_model = joblib.load('Modelo_RFC.pkl')
y_pred = tst_model.predict(tst_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 data_teste = pd.read_csv("C:\\Users\\Marcos\\Desktop\\testes-de-modelo-para-treinamento-ruidos-\\virt_env\\myenv\\arquivos\\CSV\\features_audios_testes.csv")
#       2 tst_model = joblib.load('Modelo_RFC.pkl')
# ----> 3 y_pred = tst_model.predict(tst_model)
#
# File c:\Users\Marcos\Desktop\testes-de-modelo-para-treinamento-ruidos-\.venv\Lib\site-packages\pycaret\internal\pipeline.py:328, in Pipeline.predict(self, X, **params)
#     326 @available_if(_final_estimator_has("predict"))
#     327 def predict(self, X, **params):
# --> 328     X, _ = self._memory_full_transform(self, X, None, with_final=False)
#     330     y = self.steps[-1][-1].predict(X, **params)
#     331     y = self.inverse_transform(y)
#
# ...
